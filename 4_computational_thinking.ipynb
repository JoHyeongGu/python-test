# %%
# 원의 면적 구하기
r = float(input("원의 반지름은 얼마인가? "))
result = r ** 2 * 3.141592
print(f"반지름이 {r}인 원의 면적은 {result}입니다.")
# Out:
# 원의 반지름은 얼마인가? 10.6
# 반지름이 10.6인 원의 면적은 352.98927712입니다.

# %%
# 단위 변환하기
inch = float(input("please enter an inch to convert >> "))
result = inch * 2.54
print(f"{int(inch)}inches is {result}cm")
# Out:
# please enter an inch to convert >> 30
# 30inches is 76.2cm
