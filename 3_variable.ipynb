# %%
a = 10
b = 2
print("a =", a)
print("b =", b)
print("뺄셈:", a - b)
print("덧셈:", a + b)
print("곱셈:", a * b)
print("나눗셈:", a / b)
print("나머지:", a % b)
# Out:
# a = 10
# b = 2
# 뺄셈: 8
# 덧셈: 12
# 곱셈: 20
# 나눗셈: 5.0
# 나머지: 0
